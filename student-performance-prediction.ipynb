# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
dataset = pd.read_csv('student_scores.csv')
dataset.head()
# Out:
#    Study_Hours  Attendance  Previous_Score  Final_Score
# 0            2          60              50           52
# 1            3          65              55           57
# 2            4          70              60           62
# 3            5          75              65           68
# 4            6          80              70           73

# %%
x = dataset[['Study_Hours' , 'Attendance' , 'Previous_Score']]
y = dataset['Final_Score']

x_train , x_test , y_train , y_test = train_test_split(x,y , test_size=0.2 , random_state=42)

# %%
# train model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# make predication
y_pred = model.predict(x_test)

# %%
# Evaluate the Model

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 0.8524566170667557
# R² Score: 0.9965833402121573

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Scores")
plt.ylabel("Predicted Scores")
plt.title("Actual vs Predicted Student Scores")
plt.show()

# %%
# Predict New Data

new_data = pd.DataFrame({
    'Study_Hours': [9],
    'Attendance': [92],
    'Previous_Score': [82]
})

predicted_score = model.predict(new_data)
print("Predicted Final Score:", predicted_score[0])
# Out:
# Predicted Final Score: 85.55167958828945

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.scatter(y_test, y_pred, color="royalblue", alpha=0.7, edgecolor="white", s=100)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color="crimson", linewidth=2, linestyle="--")
plt.title("📊 Actual vs Predicted Student Exam Scores", fontsize=14, fontweight="bold")
plt.xlabel("Actual Scores", fontsize=12)
plt.ylabel("Predicted Scores", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
